# %%
# %pip install langchain langchain-core langchain-community databricks-langchain
# %pip install python-dotenv
# Out:
# Requirement already satisfied: langchain in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (1.2.7)
# Requirement already satisfied: langchain-core in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (1.2.7)
# Requirement already satisfied: langchain-community in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (0.4.1)
# Requirement already satisfied: databricks-langchain in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (0.14.0)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from langchain) (1.0.7)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /databricks/python3/lib/python3.11/site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from langchain-core) (0.6.7)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /databricks/python3/lib/python3.11/site-packages (from langchain-core) (23.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /databricks/python3/lib/python3.11/site-packages (from langchain-core) (6.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /databricks/python3/lib/python3.11/site-packages (from langchain-core) (8.2.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from langchain-core) (0.14.0)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from langchain-community) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /databricks/python3/lib/python3.11/site-packages (from langchain-community) (1.4.39)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /databricks/python3/lib/python3.11/site-packages (from langchain-community) (3.8.5)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /databricks/python3/lib/python3.11/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: databricks-ai-bridge>=0.13.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from databricks-langchain) (0.13.0)
# Requirement already satisfied: databricks-mcp>=0.5.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from databricks-langchain) (0.7.0)
# Requirement already satisfied: databricks-sdk>=0.65.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from databricks-langchain) (0.82.0)
# Requirement already satisfied: databricks-vectorsearch>=0.50 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from databricks-langchain) (0.64)
# Requirement already satisfied: langchain-mcp-adapters>=0.1.13 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from databricks-langchain) (0.2.1)
# Requirement already satisfied: mlflow>=3.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from databricks-langchain) (3.9.0)
# Requirement already satisfied: openai>=1.99.9 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from databricks-langchain) (2.16.0)
# Requirement already satisfied: unitycatalog-langchain[databricks]>=0.3.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from databricks-langchain) (0.3.0)
# Requirement already satisfied: attrs>=17.3.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /databricks/python3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /databricks/python3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /databricks/python3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /databricks/python3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /databricks/python3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /databricks/python3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: mlflow-skinny>=2.19.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from databricks-ai-bridge>=0.13.0->databricks-langchain) (3.9.0)
# Requirement already satisfied: pandas>=2.2.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from databricks-ai-bridge>=0.13.0->databricks-langchain) (2.3.3)
# Requirement already satisfied: tabulate>=0.9.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from databricks-ai-bridge>=0.13.0->databricks-langchain) (0.9.0)
# Requirement already satisfied: tiktoken>=0.8.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from databricks-ai-bridge>=0.13.0->databricks-langchain) (0.12.0)
# Requirement already satisfied: mcp>=1.13.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from databricks-mcp>=0.5.1->databricks-langchain) (1.26.0)
# Requirement already satisfied: google-auth~=2.0 in /databricks/python3/lib/python3.11/site-packages (from databricks-sdk>=0.65.0->databricks-langchain) (2.21.0)
# Requirement already satisfied: protobuf!=5.26.*,!=5.27.*,!=5.28.*,!=5.29.0,!=5.29.1,!=5.29.2,!=5.29.3,!=5.29.4,!=6.30.0,!=6.30.1,!=6.31.0,<7.0,>=4.25.8 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from databricks-sdk>=0.65.0->databricks-langchain) (6.33.5)
# Requirement already satisfied: deprecation>=2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from databricks-vectorsearch>=0.50->databricks-langchain) (2.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /databricks/python3/lib/python3.11/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.21.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /databricks/python3/lib/python3.11/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /databricks/python3/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.0.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from langgraph<1.1.0,>=1.0.7->langchain) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from langgraph<1.1.0,>=1.0.7->langchain) (1.0.7)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from langgraph<1.1.0,>=1.0.7->langchain) (0.3.3)
# Requirement already satisfied: xxhash>=3.5.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from langgraph<1.1.0,>=1.0.7->langchain) (3.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /databricks/python3/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (3.10.6)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: mlflow-tracing==3.9.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from mlflow>=3.0.0->databricks-langchain) (3.9.0)
# Requirement already satisfied: Flask-CORS<7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from mlflow>=3.0.0->databricks-langchain) (6.0.2)
# Requirement already satisfied: Flask<4 in /databricks/python3/lib/python3.11/site-packages (from mlflow>=3.0.0->databricks-langchain) (2.2.5)
# Requirement already satisfied: alembic!=1.10.0,<2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from mlflow>=3.0.0->databricks-langchain) (1.18.3)
# Requirement already satisfied: cryptography<47,>=43.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from mlflow>=3.0.0->databricks-langchain) (46.0.4)
# Requirement already satisfied: docker<8,>=4.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from mlflow>=3.0.0->databricks-langchain) (7.1.0)
# Requirement already satisfied: graphene<4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from mlflow>=3.0.0->databricks-langchain) (3.4.3)
# Requirement already satisfied: gunicorn<24 in /databricks/python3/lib/python3.11/site-packages (from mlflow>=3.0.0->databricks-langchain) (20.1.0)
# Requirement already satisfied: huey<3,>=2.5.4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from mlflow>=3.0.0->databricks-langchain) (2.6.0)
# Requirement already satisfied: matplotlib<4 in /databricks/python3/lib/python3.11/site-packages (from mlflow>=3.0.0->databricks-langchain) (3.7.2)
# Requirement already satisfied: pyarrow<23,>=4.0.0 in /databricks/python3/lib/python3.11/site-packages (from mlflow>=3.0.0->databricks-langchain) (14.0.1)
# Requirement already satisfied: scikit-learn<2 in /databricks/python3/lib/python3.11/site-packages (from mlflow>=3.0.0->databricks-langchain) (1.3.0)
# Requirement already satisfied: scipy<2 in /databricks/python3/lib/python3.11/site-packages (from mlflow>=3.0.0->databricks-langchain) (1.11.1)
# Requirement already satisfied: skops<1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from mlflow>=3.0.0->databricks-langchain) (0.13.0)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /databricks/python3/lib/python3.11/site-packages (from mlflow-skinny>=2.19.0->databricks-ai-bridge>=0.13.0->databricks-langchain) (5.4.0)
# Requirement already satisfied: click<9,>=7.0 in /databricks/python3/lib/python3.11/site-packages (from mlflow-skinny>=2.19.0->databricks-ai-bridge>=0.13.0->databricks-langchain) (8.0.4)
# Requirement already satisfied: cloudpickle<4 in /databricks/python3/lib/python3.11/site-packages (from mlflow-skinny>=2.19.0->databricks-ai-bridge>=0.13.0->databricks-langchain) (2.2.1)
# Requirement already satisfied: fastapi<1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from mlflow-skinny>=2.19.0->databricks-ai-bridge>=0.13.0->databricks-langchain) (0.128.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /databricks/python3/lib/python3.11/site-packages (from mlflow-skinny>=2.19.0->databricks-ai-bridge>=0.13.0->databricks-langchain) (3.1.27)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /databricks/python3/lib/python3.11/site-packages (from mlflow-skinny>=2.19.0->databricks-ai-bridge>=0.13.0->databricks-langchain) (6.0.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /databricks/python3/lib/python3.11/site-packages (from mlflow-skinny>=2.19.0->databricks-ai-bridge>=0.13.0->databricks-langchain) (1.25.0)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from mlflow-skinny>=2.19.0->databricks-ai-bridge>=0.13.0->databricks-langchain) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /databricks/python3/lib/python3.11/site-packages (from mlflow-skinny>=2.19.0->databricks-ai-bridge>=0.13.0->databricks-langchain) (1.25.0)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from mlflow-skinny>=2.19.0->databricks-ai-bridge>=0.13.0->databricks-langchain) (1.2.1)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /databricks/python3/lib/python3.11/site-packages (from mlflow-skinny>=2.19.0->databricks-ai-bridge>=0.13.0->databricks-langchain) (0.4.2)
# Requirement already satisfied: uvicorn<1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from mlflow-skinny>=2.19.0->databricks-ai-bridge>=0.13.0->databricks-langchain) (0.40.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from openai>=1.99.9->databricks-langchain) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.99.9->databricks-langchain) (1.7.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from openai>=1.99.9->databricks-langchain) (0.12.0)
# Requirement already satisfied: sniffio in /databricks/python3/lib/python3.11/site-packages (from openai>=1.99.9->databricks-langchain) (1.2.0)
# Requirement already satisfied: tqdm>4 in /databricks/python3/lib/python3.11/site-packages (from openai>=1.99.9->databricks-langchain) (4.65.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /databricks/python3/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2023.7.22)
# Requirement already satisfied: greenlet!=0.4.17 in /databricks/python3/lib/python3.11/site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (2.0.1)
# Requirement already satisfied: unitycatalog-ai in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from unitycatalog-langchain[databricks]>=0.3.0->databricks-langchain) (0.3.2)
# Requirement already satisfied: Mako in /databricks/python3/lib/python3.11/site-packages (from alembic!=1.10.0,<2->mlflow>=3.0.0->databricks-langchain) (1.2.0)
# Requirement already satisfied: cffi>=2.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from cryptography<47,>=43.0.0->mlflow>=3.0.0->databricks-langchain) (2.0.0)
# Requirement already satisfied: Werkzeug>=2.2.2 in /databricks/python3/lib/python3.11/site-packages (from Flask<4->mlflow>=3.0.0->databricks-langchain) (2.2.3)
# Requirement already satisfied: Jinja2>=3.0 in /databricks/python3/lib/python3.11/site-packages (from Flask<4->mlflow>=3.0.0->databricks-langchain) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /databricks/python3/lib/python3.11/site-packages (from Flask<4->mlflow>=3.0.0->databricks-langchain) (2.0.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /databricks/python3/lib/python3.11/site-packages (from google-auth~=2.0->databricks-sdk>=0.65.0->databricks-langchain) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /databricks/python3/lib/python3.11/site-packages (from google-auth~=2.0->databricks-sdk>=0.65.0->databricks-langchain) (4.9)
# Requirement already satisfied: six>=1.9.0 in /usr/lib/python3/dist-packages (from google-auth~=2.0->databricks-sdk>=0.65.0->databricks-langchain) (1.16.0)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from graphene<4->mlflow>=3.0.0->databricks-langchain) (3.2.7)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from graphene<4->mlflow>=3.0.0->databricks-langchain) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /databricks/python3/lib/python3.11/site-packages (from graphene<4->mlflow>=3.0.0->databricks-langchain) (2.8.2)
# Requirement already satisfied: setuptools>=3.0 in /databricks/python3/lib/python3.11/site-packages (from gunicorn<24->mlflow>=3.0.0->databricks-langchain) (68.0.0)
# Requirement already satisfied: httpcore==1.* in /databricks/python3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /databricks/python3/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (0.14.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.7->langchain) (1.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in /databricks/python3/lib/python3.11/site-packages (from matplotlib<4->mlflow>=3.0.0->databricks-langchain) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /databricks/python3/lib/python3.11/site-packages (from matplotlib<4->mlflow>=3.0.0->databricks-langchain) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /databricks/python3/lib/python3.11/site-packages (from matplotlib<4->mlflow>=3.0.0->databricks-langchain) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /databricks/python3/lib/python3.11/site-packages (from matplotlib<4->mlflow>=3.0.0->databricks-langchain) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /databricks/python3/lib/python3.11/site-packages (from matplotlib<4->mlflow>=3.0.0->databricks-langchain) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /databricks/python3/lib/python3.11/site-packages (from matplotlib<4->mlflow>=3.0.0->databricks-langchain) (3.0.9)
# Requirement already satisfied: jsonschema>=4.20.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from mcp>=1.13.0->databricks-mcp>=0.5.1->databricks-langchain) (4.26.0)
# Requirement already satisfied: pyjwt[crypto]>=2.10.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from mcp>=1.13.0->databricks-mcp>=0.5.1->databricks-langchain) (2.11.0)
# Requirement already satisfied: python-multipart>=0.0.9 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from mcp>=1.13.0->databricks-mcp>=0.5.1->databricks-langchain) (0.0.22)
# Requirement already satisfied: sse-starlette>=1.6.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from mcp>=1.13.0->databricks-mcp>=0.5.1->databricks-langchain) (3.2.0)
# Requirement already satisfied: starlette>=0.27 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from mcp>=1.13.0->databricks-mcp>=0.5.1->databricks-langchain) (0.50.0)
# Requirement already satisfied: pytz>=2020.1 in /databricks/python3/lib/python3.11/site-packages (from pandas>=2.2.0->databricks-ai-bridge>=0.13.0->databricks-langchain) (2022.7)
# Requirement already satisfied: tzdata>=2022.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from pandas>=2.2.0->databricks-ai-bridge>=0.13.0->databricks-langchain) (2025.3)
# Requirement already satisfied: joblib>=1.1.1 in /databricks/python3/lib/python3.11/site-packages (from scikit-learn<2->mlflow>=3.0.0->databricks-langchain) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /databricks/python3/lib/python3.11/site-packages (from scikit-learn<2->mlflow>=3.0.0->databricks-langchain) (2.2.0)
# Requirement already satisfied: prettytable>=3.9 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from skops<1->mlflow>=3.0.0->databricks-langchain) (3.17.0)
# Requirement already satisfied: regex>=2022.1.18 in /databricks/python3/lib/python3.11/site-packages (from tiktoken>=0.8.0->databricks-ai-bridge>=0.13.0->databricks-langchain) (2022.7.9)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /databricks/python3/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.4.3)
# Requirement already satisfied: nest-asyncio in /databricks/python3/lib/python3.11/site-packages (from unitycatalog-ai->unitycatalog-langchain[databricks]>=0.3.0->databricks-langchain) (1.5.6)
# Requirement already satisfied: unitycatalog-client in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from unitycatalog-ai->unitycatalog-langchain[databricks]>=0.3.0->databricks-langchain) (0.3.1)
# Requirement already satisfied: databricks-connect<17.1,>=15.1.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from unitycatalog-ai->unitycatalog-langchain[databricks]>=0.3.0->databricks-langchain) (16.1.7)
# Requirement already satisfied: pycparser in /databricks/python3/lib/python3.11/site-packages (from cffi>=2.0.0->cryptography<47,>=43.0.0->mlflow>=3.0.0->databricks-langchain) (2.21)
# Requirement already satisfied: googleapis-common-protos>=1.56.4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from databricks-connect<17.1,>=15.1.0->unitycatalog-ai->unitycatalog-langchain[databricks]>=0.3.0->databricks-langchain) (1.72.0)
# Requirement already satisfied: grpcio-status>=1.59.3 in /databricks/python3/lib/python3.11/site-packages (from databricks-connect<17.1,>=15.1.0->unitycatalog-ai->unitycatalog-langchain[databricks]>=0.3.0->databricks-langchain) (1.60.0)
# Requirement already satisfied: grpcio>=1.59.3 in /databricks/python3/lib/python3.11/site-packages (from databricks-connect<17.1,>=15.1.0->unitycatalog-ai->unitycatalog-langchain[databricks]>=0.3.0->databricks-langchain) (1.60.0)
# Requirement already satisfied: py4j==0.10.9.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from databricks-connect<17.1,>=15.1.0->unitycatalog-ai->unitycatalog-langchain[databricks]>=0.3.0->databricks-langchain) (0.10.9.7)
# Requirement already satisfied: annotated-doc>=0.0.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from fastapi<1->mlflow-skinny>=2.19.0->databricks-ai-bridge>=0.13.0->databricks-langchain) (0.0.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /databricks/python3/lib/python3.11/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny>=2.19.0->databricks-ai-bridge>=0.13.0->databricks-langchain) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in /databricks/python3/lib/python3.11/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny>=2.19.0->databricks-ai-bridge>=0.13.0->databricks-langchain) (3.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /databricks/python3/lib/python3.11/site-packages (from Jinja2>=3.0->Flask<4->mlflow>=3.0.0->databricks-langchain) (2.1.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp>=1.13.0->databricks-mcp>=0.5.1->databricks-langchain) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp>=1.13.0->databricks-mcp>=0.5.1->databricks-langchain) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp>=1.13.0->databricks-mcp>=0.5.1->databricks-langchain) (0.30.0)
# Requirement already satisfied: deprecated>=1.2.6 in /databricks/python3/lib/python3.11/site-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny>=2.19.0->databricks-ai-bridge>=0.13.0->databricks-langchain) (1.2.14)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.46b0 in /databricks/python3/lib/python3.11/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny>=2.19.0->databricks-ai-bridge>=0.13.0->databricks-langchain) (0.46b0)
# Requirement already satisfied: wcwidth in /databricks/python3/lib/python3.11/site-packages (from prettytable>=3.9->skops<1->mlflow>=3.0.0->databricks-langchain) (0.2.5)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /databricks/python3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk>=0.65.0->databricks-langchain) (0.4.8)
# Requirement already satisfied: aiohttp-retry>=2.8.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (from unitycatalog-client->unitycatalog-ai->unitycatalog-langchain[databricks]>=0.3.0->databricks-langchain) (2.9.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /databricks/python3/lib/python3.11/site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny>=2.19.0->databricks-ai-bridge>=0.13.0->databricks-langchain) (1.14.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /databricks/python3/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny>=2.19.0->databricks-ai-bridge>=0.13.0->databricks-langchain) (5.0.0)
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.
# Requirement already satisfied: python-dotenv in /local_disk0/.ephemeral_nfs/envs/pythonEnv-fcc411ff-d7be-4eeb-b7b9-61f78417b2f5/lib/python3.11/site-packages (1.2.1)
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
dbutils.library.restartPython()

# %%
from pyspark.sql import functions as F
from dotenv import load_dotenv  
import os


load_dotenv()

# ==============================================================================
# STEP 1: Load "Submissions" Data (Matches & Stadiums)
# ==============================================================================


# 1. Define variables for the First Container
storage_account = "lab94290"
container_submissions = "submissions"
sas_token_submissions = os.getenv('SAS_SUBMISSIONS')
sas_token_submissions = sas_token_submissions.lstrip('?')

# 2. Configure Spark for Submissions
print("🔄 Connecting to 'submissions' container...")
spark.conf.set(f"fs.azure.account.auth.type.{storage_account}.dfs.core.windows.net", "SAS")
spark.conf.set(f"fs.azure.sas.token.provider.type.{storage_account}.dfs.core.windows.net", "org.apache.hadoop.fs.azurebfs.sas.FixedSASTokenProvider")
spark.conf.set(f"fs.azure.sas.fixed.token.{storage_account}.dfs.core.windows.net", sas_token_submissions)
# 3. Load Data
base_path_submissions = f"abfss://{container_submissions}@{storage_account}.dfs.core.windows.net/Lior_Shachar_Raz/"



stadium_enrichment_df = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load(f"{base_path_submissions}Stadium_LLM_Enrichment.csv")



# 5. CRITICAL: Cache into RAM
# We must do this NOW because we are about to change the SAS token. 
# If we don't cache, Spark will try to read the files again later and fail.
print("⏳ Caching Match and Stadium data into RAM...")
stadium_enrichment_df = stadium_enrichment_df.cache()

# Trigger an action (.count()) to force the data into memory immediately
print(f"   - Stadiums loaded: {stadium_enrichment_df.count()} rows")

print("Stadium Enrichment:")
display(stadium_enrichment_df.limit(5))
# Out:
# 🔄 Connecting to 'submissions' container...
# ⏳ Caching Match and Stadium data into RAM...
#    - Stadiums loaded: 274 rows
# Stadium Enrichment:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th
# %%
# ==============================================================================
# Part Y: Generate Stadium Guides JSON and Integrate into HTML
# ==============================================================================

import requests
import json
import time

# Load stadium data
stadiums_df = stadium_enrichment_df.toPandas()
# ------------------------------------------------------------------------------
# Function to call LLM and generate stadium guide
# ------------------------------------------------------------------------------
def generate_stadium_guide(team, stadium, directions, food_and_stay, ticket_info):
    """
    Generates a user-friendly guide for a stadium using LLM
    """
    # Handle missing values
    directions = directions if directions and str(directions) != "nan" and directions != "Info not available" else "Information not available"
    food_and_stay = food_and_stay if food_and_stay and str(food_and_stay) != "nan" and food_and_stay != "Info not available" else "Information not available"
    ticket_info = ticket_info if ticket_info and str(ticket_info) != "nan" and ticket_info != "Info not available" else "Information not available"
    
    # If all info is missing, return appropriate message
    if all(x == "Information not available" for x in [directions, food_and_stay, ticket_info]):
        return "No information available for this stadium."
    
    prompt = f"""Create a SHORT guide for {stadium} ({team}). MAX 120 words total.

RAW DATA:
- Directions: {directions}
- Food/Stay: {food_and_stay}
- Tickets: {ticket_info}

Format:
🚗 **Getting There** (3 bullet points)
🍽️ **Food & Stay** (2-3 bullet points)
🎫 **Tickets** (1-2 bullet points only - just price range and where to buy)

Rules: 
- Be very brief. Only essential facts. No intro/outro.
- If a section has "Information not available", SKIP that section entirely. Do not print it."""

    # Call LLM via Databricks Foundation Model API
    try:
        from databricks.sdk import WorkspaceClient
        from databricks.sdk.service.serving import ChatMessage, ChatMessageRole
        
        w = WorkspaceClient()
        
        response = w.serving_endpoints.query(
            name="databricks-meta-llama-3-3-70b-instruct",
            messages=[
                ChatMessage(
                    role=ChatMessageRole.USER,
                    content=prompt
                )
            ],
            max_tokens=400,
            temperature=0.7
        )
        
        return response.choices[0].message.content
        
    except Exception as e:
        # Fallback: Use direct REST API
        try:
            token = dbutils.notebook.entry_point.getDbutils().notebook().getContext().apiToken().get()
            host = spark.conf.get("spark.databricks.workspaceUrl")
            
            url = f"https://{host}/serving-endpoints/databricks-meta-llama-3-3-70b-instruct/invocations"
            
            headers = {
                "Authorization": f"Bearer {token}",
                "Content-Type": "application/json"
            }
            
            payload = {
                "messages": [
                    {"role": "user", "content": prompt}
                ],
                "max_tokens": 400,
                "temperature": 0.7
            }
            
            response = requests.post(url, headers=headers, json=payload, timeout=60)
            response.raise_for_status()
            
            result = response.json()
            return result["choices"][0]["message"]["content"]
            
        except Exception as e2:
            return f"Error generating guide: {str(e2)}"


# ------------------------------------------------------------------------------
# Generate guides for all stadiums and create JSON
# ------------------------------------------------------------------------------
def create_stadium_guides_dict(batch_size=10, delay_seconds=3):
    """
    Generate guides for all stadiums
    Returns dictionary keyed by stadium name
    """
    guides_dict = {}
    total = len(stadiums_df)
    
    print(f"🚀 Generating guides for {total} stadiums...")
    
    for i, row in stadiums_df.iterrows():
        # Key by stadium name for easy lookup
        stadium_key = row['Stadium']
        
        print(f"Processing {i+1}/{total}: {row['Stadium']}...")
        
        guide = generate_stadium_guide(
            row["Team"],
            row["Stadium"],
            row["Directions"],
            row["Food_and_Stay"],
            row["Ticket_Info"]
        )
        
        guides_dict[stadium_key] = {
            "team": row["Team"],
            "stadium": row["Stadium"],
            "country": row["Country"],
            "league": row["League"],
            "guide": guide
        }
        
        # Rate limiting protection
        if (i + 1) % batch_size == 0 and (i + 1) < total:
            print(f"⏳ Waiting {delay_seconds} seconds...")
            time.sleep(delay_seconds)
    
    print(f"✅ Successfully generated {total} guides!")
    return guides_dict


# Generate the guides
stadium_guides = create_stadium_guides_dict()

# Convert to JSON string for HTML embedding
stadium_guides_json = json.dumps(stadium_guides, ensure_ascii=False)

print(f"\n📦 Stadium guides JSON ready! ({len(stadium_guides)} stadiums)")

# ==============================================================================
# Part Z: Save and Create Download Link
# ==============================================================================

# 1. Define the filename and target path in Databricks FileStore
file_name = "stadium_guides.json"
dbfs_path = f"dbfs:/FileStore/{file_name}"

# 2. Save the JSON string to DBFS
# We use dbutils.fs.put to write directly to the distributed storage
try:
    dbutils.fs.put(dbfs_path, stadium_guides_json, overwrite=True)
    print(f"✅ File saved successfully to: {dbfs_path}")
except Exception as e:
    print(f"❌ Error saving file: {str(e)}")

# 3. Generate a Download Button
# The '/files/' path maps to 'dbfs:/FileStore/' in the workspace URL
html_button = f"""
<div style="margin-top: 20px;">
    <h3>🎉 Processing Complete</h3>
    <p>Your stadium data is ready.</p>
    <a href="/files/{file_name}" download>
        <button style="
            background-color: #1E88E5; 
            color: white; 
            padding: 12px 24px; 
            border: none; 
            border-radius: 4px; 
            font-size: 16px; 
            cursor: pointer;
            font-weight: bold;">
            ⬇️ Download stadium_guides.json
        </button>
    </a>
</div>
"""

# 4. Render the HTML in the notebook
displayHTML(html_button)
# Out:
# 🚀 Generating guides for 274 stadiums...
# Processing 1/274: Emirates Stadium...
# Processing 2/274: Villa Park...
# Processing 3/274: Dean Court...
# Processing 4/274: Brentford Community Stadium...
# Processing 5/274: Falmer Stadium...
# Processing 6/274: Stamford Bridge...
# Processing 7/274: Selhurst Park...
# Processing 8/274: Goodison Park...
# Processing 9/274: Craven Cottage...
# Processing 10/274: Portman Road...
# ⏳ Waiting 3 seconds...
# Processing 11/274: King Power Stadium...
# Processing 12/274: Anfield...
# Processing 13/274: City of Manchester Stadium...
# Processing 14/274: Old Trafford...
# Processing 15/274: St James' Park...
# Processing 16/274: City Ground...
# Processing 17/274: St Mary's Stadium...
# Processing 18/274: Tottenham Hotspur Stadium...
# Processing 19/274: London Stadium...
# Processing 20/274: Molineux Stadium...
# ⏳ Waiting 3 seconds...
# Processing 21/274: Mendizorrotza...
# Processing 22/274: San Mamés...
# Processing 23/274: Metropolitano...
# Processing 24/274: Olímpic Lluís Companys...
# Processing 25/274: Balaídos...
# Processing 26/274: RCDE Stadium...
# Processing 27/274: Coliseum...
# Processing 28/274: Montilivi...
# Processing 29/274: Gran Canaria...
# Processing 30/274: Municipal de Butarque...
# ⏳ Waiting 3 seconds...
# Processing 225/274: Enea Stadium...
# Processing 226/274: Polsat Plus Arena Gdańsk...
# Processing 227/274: Polish Army Stadium...
# Processing 228/274: Motor Lublin Arena...
# Processing 229/274: Piotr Wieczorek Stadium...
# Processing 230/274: Florian Krygier Stadium...
# ⏳ Waiting 3 seconds...
# Processing 231/274: Józef Piłsudski Cracovia Stadium3Municipal Stadium...
# Processing 232/274: Czachor Brothers Stadium...
# Processing 233/274: Raków Municipal Football Stadium...
# Processing 234/274: Grzegorz Lato Stadium...
# Processing 235/274: Tarczyński Arena Wrocław...
# Processing 236/274: Widzew Łódź Stadium...
# Processing 237/274: KGHM Zagłebie Arena...
# Processing 238/274: Arena Lviv...
# Processing 239/274: Arena Lviv...
# Processing 240/274: Arena Lviv...
# ⏳ Waiting 3 seconds...
# Processing 241/274: Chornomorets Stadium...
# Processing 242/274: Chornomorets Stadium...
# Processing 243/274: Ukraina Stadium...
# Processing 244/274: Ukraina Stadium...
# Processing 245/274: Butovsky Vorskla Stadium...
# Processing 246/274: Lobanovskyi Dynamo Stadium...
# Processing 247/274: Lobanovskyi Dynamo Stadium...
# Processing 248/274: Lobanovskyi Dynamo Stadium...
# Processing 249/274: Tsentralnyi Stadion...
# Processing 250/274: Avanhard Stadium...
# ⏳ Waiting 3 seconds...
# Processing 251/274: Avanhard Stadium...
# Processing 252/274: CSC Nika Stadium...
# Processing 253/274: CSC Nika Stadium...
# Processing 254/274: Tsentralnyi Stadion...
# Processing 255/274: Tsentralnyi Stadion...
# Processing 256/274: Tsentralnyi Stadion...
# Processing 257/274: Obolon Arena...
# Processing 258/274: Obolon Arena...
# Processing 259/274: Kolos Stadium...
# Processing 260/274: Kolos Stadium...
# ⏳ Waiting 3 seconds...
# Processing 261/274: Kolos Stadium...
# Processing 262/274: Arena Livyi Bereh...
# Processing 263/274: Arena Livyi Bereh...
# Processing 264/274: Berezkin Zirka Stadium...
# Processing 265/274: Maksimir...
# Processing 266/274: ŠRC Velika Gorica...
# Processing 267/274: Poljud...
# Processing 268/274: Stadion Aldo Drosina...
# Processing 269/274: Kranjčevićeva1...
# Processing 270/274: Opus Arena...
# ⏳ Waiting 3 seconds...
# Processing 271/274: Rujevica...
# Processing 272/274: Stadion Ivan Kušek-Apaš...
# Processing 273/274: Šubićevac...
# Processing 274/274: Stadion Varteks...
# ✅ Successfully generated 274 guides!
#
# 📦 Stadium guides JSON ready! (254 stadiums)
# Wrote 128343 bytes.
# ✅ File saved successfully to: dbfs:/FileStore/stadium_guides.json
# <div style="margin-top: 20px;">
#     <h3>🎉 Processing Complete</h3>
#     <p>Your stadium data is ready.</p>
#     <a href="/files/stadium_guides.json" download>
#         <button style="
#             background-color: #1E88E5;
#             color: white;
#             padding: 12px 24px;
#             border: none;
#             border-radius: 4px;
#             font-size: 16px;
#             cursor: pointer;
#             font-weight: bold;">
#             ⬇️ Download stadium_guides.json
#         </button>
#     </a>
# </div>
